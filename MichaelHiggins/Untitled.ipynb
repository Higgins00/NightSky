# %%
import numpy as np
import pandas as pd
import astropy.units as u
from astropy.time import Time
from astropy.coordinates import SkyCoord
import pytz

from astroplan import Observer, FixedTarget

#Plotting Airmass
# %matplotlib inline
import matplotlib.pyplot as plt

from astroplan import time_grid_from_range

from astroplan.plots import plot_airmass

# %%
pd.read_csv("randomUGC.csv")
# Out:
#         Name
# 0   UGC10492
# 1    UGC3104
# 2     UGC439
# 3   UGC12479
# 4     UGC965
# 5     UGC991
# 6    UGC8820
# 7    UGC1052
# 8    UGC3170
# 9    UGC1092
# 10   UGC7545
# 11   UGC1727
# 12   UGC2343
# 13   UGC1713
# 14     UGC72
# 15   UGC5985
# 16   UGC3226
# 17   UGC2600
# 18  UGC12174
# 19   UGC6200
# 20  UGC12637
# 21  UGC12348
# 22  UGC11628
# 23   UGC8391
# 24  UGC10081
# 25   UGC4492
# 26   UGC6180
# 27   UGC2292
# 28   UGC2147
# 29  UGC12220
# 30   UGC7833
# 31  UGC12225
# 32   UGC2158
# 33   UGC2152
# 34   UGC9960
# 35   UGC7021
# 36   UGC8021
# 37  UGC10268
# 38  UGC12349
# 39    UGC382
# 40   UGC6373
# 41   UGC3213
# 42  UGC10184
# 43   UGC5525
# 44   UGC7036
# 45   UGC6351
# 46   UGC9863
# 47   UGC7804
# 48   UGC8857

# %%
#Observing from observatory location
het =  Observer(longitude = -105.820278 * u.deg,
        latitude = 32 * u.deg + 46 * u.arcmin + 49 * u.arcsec,
        elevation = 2788 * u.m,
        timezone = 'Mexico/BajaSur',
        name = "Apache Point Observatory"
        )
